# %% [markdown]
# # Project NEURA — First Dataset Exploration
#
# Use this notebook only after the provider dataset has been placed under `data/raw/`.
#
# **Do not modify the original raw files.**

# %%
from pathlib import Path
import pandas as pd

from neura.intake import inventory

RAW = Path('../data/raw').resolve()
files = pd.DataFrame(inventory(RAW))
files.head(20)

# %% [markdown]
# ## Before loading anything large
#
# Record the file format, sizes, dataset documentation, sampling rate, signal units, channel mapping and any event/stimulation metadata. Then add a format-specific loader rather than guessing.
